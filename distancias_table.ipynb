# %% [markdown]
# # Generar Matriz de Distancias
#
# ### Instrucciones:
#
# - **a. Origenes**
#   - Es una capa shapefile de polígonos con los campos que quiero calcular.
#   - Tiene que tener los nombres de los campos en una columna llamada `"idest"`.
#   - En general, esta capa es la capa de cultivos o una parte de ella.
#
# - **b. Destinos**
#   - Es una capa shapefile de puntos con los destinos.
#   - Debe tener la columna `"Localidad"` con las localidades de los puertos, molinos o acopios de la capa.

# %%
import pandas as pd
import geopandas as gpd
import osmnx as ox
import datetime as datetime
import os
from pathlib import Path
import time
import requests

# %%
try:
  espcul_gdf = gpd.read_file('./inputs/origenes.shp')

except Exception as e:
  espcul_gdf = gpd.read_file('./inputs/origenes.gpkg')

espcul_gdf = espcul_gdf.loc[espcul_gdf.campania == '24/25']

espcul_gdf = espcul_gdf[['zona', 'idest', 'geometry']]

espcul_gdf = espcul_gdf.loc[espcul_gdf.zona.isin(['LA PAMPA'])]

espcul_gdf = gpd.GeoDataFrame(espcul_gdf, geometry='geometry').reset_index()
espcul_gdf['geometry'] = espcul_gdf.buffer(0.0001)
espcul_dissolve = espcul_gdf.dissolve(by='idest').reset_index()

print(f"espcul_dissolve.shape: {espcul_dissolve.shape}")
print(f"espcul_gdf.shape: {espcul_gdf.shape}")
espcul_dissolve.head()
# Out:
# /var/folders/xt/0fzdrsd52bj4z2cqvy77d5w00000gn/T/ipykernel_67951/1523788186.py:14: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   espcul_gdf['geometry'] = espcul_gdf.buffer(0.0001)
# espcul_dissolve.shape: (5, 4)
# espcul_gdf.shape: (112, 4)
#                   idest                                           geometry  \
# 0               Atreuco  MULTIPOLYGON (((-63.8251 -37.10477, -63.82509 ...
# 1             La Merced  POLYGON ((-63.57368 -36.91905, -63.57369 -36.9...
# 2  Los Robles Lonquimay  MULTIPOLYGON (((-63.8182 -36.57147, -63.8182 -...
# 3         San Francisco  POLYGON ((-63.49687 -36.74051, -63.49687 -36.7...
# 4       Valle Argentino  MULTIPOLYGON (((-63.90649 -37.21337, -63.90649...
#
#    index      zona
# 0    144  LA PAMPA
# 1     93  LA PAMPA
# 2    112  LA PAMPA
# 3    929  LA PAMPA
# 4    145  LA PAMPA

# %%
# origen_zona = {"O1": "BA SDE S", "O2": "BA SDE S"}
origen_zona = {}
for i in range(len(espcul_gdf)):
    origen_zona[espcul_gdf['idest'][i]] = espcul_gdf['zona'][i]

# %%
zonas_list = espcul_gdf.zona.unique()
zonas_list
# Out:
# array(['LA PAMPA'], dtype=object)

# %%
espcul_dissolve['x']= espcul_dissolve['geometry'].centroid.x
espcul_dissolve['y']= espcul_dissolve['geometry'].centroid.y
espcul_dissolve['centres']= espcul_dissolve['geometry'].centroid
espcul_centroids = espcul_dissolve.loc[:,['idest','x','y','centres']].copy()
espcul_centroids = espcul_centroids.rename(columns = {'centres': 'geometry'})
espcul_centroids = espcul_centroids.to_crs('EPSG:4326')
print(f"espcul_centroids: {espcul_centroids.shape[0]}")
espcul_centroids.head()
# Out:
# espcul_centroids: 5
# /var/folders/xt/0fzdrsd52bj4z2cqvy77d5w00000gn/T/ipykernel_67951/1240167303.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   espcul_dissolve['x']= espcul_dissolve['geometry'].centroid.x
# /var/folders/xt/0fzdrsd52bj4z2cqvy77d5w00000gn/T/ipykernel_67951/1240167303.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   espcul_dissolve['y']= espcul_dissolve['geometry'].centroid.y
# /var/folders/xt/0fzdrsd52bj4z2cqvy77d5w00000gn/T/ipykernel_67951/1240167303.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   espcul_dissolve['centres']= espcul_dissolve['geometry'].centroid
#                   idest          x          y                     geometry
# 0               Atreuco -63.815498 -37.088294   POINT (-63.8155 -37.08829)
# 1             La Merced -63.553689 -36.897663  POINT (-63.55369 -36.89766)
# 2  Los Robles Lonquimay -63.784198 -36.565025   POINT (-63.7842 -36.56502)
# 3         San Francisco -63.483646 -36.749309  POINT (-63.48365 -36.74931)
# 4       Valle Argentino -63.915926 -37.191708  POINT (-63.91593 -37.19171)

# %%
espcul_centroids.to_file(driver = "GPKG",filename='./inputs/centoids.gpkg', encoding='utf-8', index=False)

# %%
espcul_coord = {}

for i in range(0, len(espcul_centroids)):
    origin = espcul_centroids['idest'][i]
    x = espcul_centroids['geometry'][i].x
    y = espcul_centroids['geometry'][i].y
    coords = (y, x)
    espcul_coord[origin]=coords
# espcul_coord

# %%
try:
  destinos_gdf = gpd.read_file('./inputs/destinos.shp')

except Exception as e:
  destinos_gdf = gpd.read_file('./inputs/destinos.gpkg')


print(destinos_gdf.shape)
destinos_gdf.head()

destinos_coord = {}

for i in range(len(destinos_gdf)):
    destino = destinos_gdf['Localidad'][i]
    punto = destinos_gdf['geometry'][i].centroid
    coords = (punto.y, punto.x)
    destinos_coord[destino] = coords

list(destinos_coord.items())[:4]
# Out:
# (69, 12)
# [('9 de Julio', (-35.44393528, -60.88462748)),
#  ('Arrecifes', (-34.06751491, -60.10869159)),
#  ('Azul', (-36.777447, -59.86344305)),
#  ('Bahia Blanca', (-38.71760509, -62.26544693))]

# %% [markdown]
# The centroids may be away form actual street network. Use osmnx to find the closest node on OSM network for routing

# %%
arr = espcul_gdf.to_crs('EPSG:4326').total_bounds
tupla = tuple(arr)
# print(tupla)

# %%
G = ox.graph.graph_from_bbox(tupla, network_type='drive')
nodes = G.nodes()

# %%
espcul_coord_snapped = {}
for name, coords in espcul_coord.items():
    node = ox.distance.nearest_nodes(G, coords[1], coords[0])
    info = nodes[node]
    espcul_coord_snapped[name] = (info['y'], info['x'])

espcul_coord_snapped
# Out:
# {'Atreuco': (-37.0952312, -63.8351522),
#  'La Merced': (-36.9190191, -63.5534875),
#  'Los Robles Lonquimay': (-36.5374728, -63.7769719),
#  'San Francisco': (-36.7629028, -63.497029),
#  'Valle Argentino': (-37.1679942, -63.9040107)}

# %%
service = 'table'
version = 'v1'
profile = 'driving'

# %%
# Build list of all coordinates (espcul_coord_snapped first, then destinos_coord)
all_coords = []
# To keep track of index mapping
origin_keys = list(espcul_coord_snapped.keys())
dest_keys = list(destinos_coord.keys())

for key in origin_keys:
    o = espcul_coord_snapped[key]
    # OSRM expects lon,lat; our tuples are (lat, lon) so index [1] is lon, [0] is lat
    all_coords.append(f"{o[1]},{o[0]}")

for key in dest_keys:
    d = destinos_coord[key]
    # Same format: (lat, lon) so we use [1] for lon, [0] for lat
    all_coords.append(f"{d[1]},{d[0]}")

# Build the coordinate string
coords_str = ";".join(all_coords)

# Build sources indices: since espcul_coord_snapped are first in the list, their indices = 0..len(espcul_coord_snapped)-1
sources_indices = ";".join(str(i) for i in range(len(origin_keys)))

# Build destinos_coord indices: destinos_coord start at index len(espcul_coord_snapped)
# Build destination indices: destinos_coord start at index len(espcul_coord_snapped)
dest_start = len(origin_keys)
dest_indices = ";".join(str(dest_start + i) for i in range(len(dest_keys)))

# Build the request URL
profile = "driving"  # or "bike"/"foot" according to your case
port = 5001  # local OSRM server port
base_url = f"http://localhost:{port}"  # local OSRM server
url = (
    f"{base_url}/table/v1/{profile}/{coords_str}"
    f"?sources={sources_indices}&destinations={dest_indices}&annotations=distance"
)

# Send the request
resp = requests.get(url)
resp.raise_for_status()
data = resp.json()

# Check for successful code
if data.get("code") != "Ok":
    raise Exception(f"OSRM table error: {data.get('code')}")

# Extract distances matrix (in meters)
distances = data.get("distances")

# Map results to list of dicts with origen, destino, distancia keys
results = []
for i, orig_key in enumerate(origin_keys):
    for j, dest_key in enumerate(dest_keys):
        # Convert from meters to kilometers
        results.append({
            'origen': orig_key,
            'destino': dest_key,
            'distancia': distances[i][j] / 1000
        })

print(results)
# Out:
# [{'origen': 'Atreuco', 'destino': '9 de Julio', 'distancia': 378.688}, {'origen': 'Atreuco', 'destino': 'Arrecifes', 'distancia': 595.1990999999999}, {'origen': 'Atreuco', 'destino': 'Azul', 'distancia': 457.811}, {'origen': 'Atreuco', 'destino': 'Bahia Blanca', 'distancia': 298.5912}, {'origen': 'Atreuco', 'destino': 'Barker', 'distancia': 480.9814}, {'origen': 'Atreuco', 'destino': 'Benito Juarez', 'distancia': 431.5583}, {'origen': 'Atreuco', 'destino': 'Bragado', 'distancia': 432.414}, {'origen': 'Atreuco', 'destino': 'Brandsen', 'distancia': 629.1041}, {'origen': 'Atreuco', 'destino': 'Ramallo', 'distancia': 663.796}, {'origen': 'Atreuco', 'destino': 'Cañuelas', 'distancia': 565.5233000000001}, {'origen': 'Atreuco', 'destino': 'Capilla del Señor', 'distancia': 612.1795999999999}, {'origen': 'Atreuco', 'destino': 'Laboulaye', 'distancia': 472.241}, {'origen': 'Atreuco', 'destino': 'Los Cisnes', 'distancia': 585.207}, {'origen': 'Atreuco', 'destino': 'Rio Cuarto', 'distancia': 496.84590000000003}, {'origen': 'Atreuco', 'destino': 'Chacabuco', 'distancia': 521.5346}, {'origen': 'Atreuco', 'destino': 'Cofco Balcarce', 'distancia': 646.0515}, {'origen': 'Atreuco', 'destino': 'Concepción del Uruguay', 'distancia': 839.7955999999999}, {'origen': 'Atreuco', 'destino': 'Deheza', 'distancia': 566.6472}, {'origen': 'Atreuco', 'destino': 'Villa Paranacito', 'distancia': 719.1871}, {'origen': 'Atreuco', 'destino': 'Dovales (Tandil)', 'distancia': 539.9815}, {'origen': 'Atreuco', 'destino': 'Flor de Oro, Reconquista', 'distancia': 1137.7476000000001}, {'origen': 'Atreuco', 'destino': 'Gral. Levalle', 'distancia': 451.62309999999997}, {'origen': 'Atreuco', 'destino': 'H. Lagos ', 'distancia': 679.266}, {'origen': 'Atreuco', 'destino': 'La Carlota', 'distancia': 561.1493}, {'origen': 'Atreuco', 'destino': 'Laplacette', 'distancia': 452.685}, {'origen': 'Atreuco', 'destino': 'La Toma (PALADINI)', 'distancia': 613.5025}, {'origen': 'Atreuco', 'destino': 'Labordeboy', 'distancia': 577.546}, {'origen': 'Atreuco', 'destino': 'Lincoln', 'distancia': 416.8451}, {'origen': 'Atreuco', 'destino': 'Lobos', 'distancia': 531.677}, {'origen': 'Atreuco', 'destino': 'Madariaga', 'distancia': 733.0097}, {'origen': 'Atreuco', 'destino': 'Naón', 'distancia': 416.6582}, {'origen': 'Atreuco', 'destino': 'Navarro', 'distancia': 556.471}, {'origen': 'Atreuco', 'destino': 'Otamendi', 'distancia': 632.3721999999999}, {'origen': 'Atreuco', 'destino': 'Pehuajó', 'distancia': 275.7457}, {'origen': 'Atreuco', 'destino': 'Pergamino', 'distancia': 565.7888}, {'origen': 'Atreuco', 'destino': 'Peyrano', 'distancia': 614.3936}, {'origen': 'Atreuco', 'destino': 'Pieres', 'distancia': 553.3301}, {'origen': 'Atreuco', 'destino': 'Pilar', 'distancia': 594.3711}, {'origen': 'Atreuco', 'destino': 'Roldán', 'distancia': 650.2961}, {'origen': 'Atreuco', 'destino': 'Rosario', 'distancia': 703.2675}, {'origen': 'Atreuco', 'destino': 'Saladillo', 'distancia': 448.5775}, {'origen': 'Atreuco', 'destino': 'Salto', 'distancia': 568.2455}, {'origen': 'Atreuco', 'destino': 'San Andrés de Giles', 'distancia': 567.476}, {'origen': 'Atreuco', 'destino': 'San Jerónimo', 'distancia': 655.9472}, {'origen': 'Atreuco', 'destino': 'San Pedro', 'distancia': 660.0485}, {'origen': 'Atreuco', 'destino': 'Tres Arroyos', 'distancia': 392.81109999999995}, {'origen': 'Atreuco', 'destino': 'Vicuña Mackena ', 'distancia': 403.2253}, {'origen': 'Atreuco', 'destino': 'Villa Elisa', 'distancia': 640.3311}, {'origen': 'Atreuco', 'destino': 'Villegas', 'distancia': 307.1173}, {'origen': 'Atreuco', 'destino': 'Carlos Casares', 'distancia': 327.0477}, {'origen': 'Atreuco', 'destino': 'Colón', 'distancia': 571.0078000000001}, {'origen': 'Atreuco', 'destino': 'Chascomús', 'distancia': 696.236}, {'origen': 'Atreuco', 'destino': 'Chivilcoy', 'distancia': 483.02979999999997}, {'origen': 'Atreuco', 'destino': 'Daireaux', 'distancia': 235.2}, {'origen': 'Atreuco', 'destino': 'Guaminí', 'distancia': 155.14620000000002},  ...

# %%
distances_dict = {}

for k, v in results.items():
    for k2, v2 in v.items():
        origen = k
        destino = k2
        distancia = v2
        distances_dict[(origen, destino)] = distancia

distances_dict
# Out:
# {('Atreuco', '9 de Julio'): 378.688,
#  ('Atreuco', 'Arrecifes'): 595.1990999999999,
#  ('Atreuco', 'Azul'): 457.811,
#  ('Atreuco', 'Bahia Blanca'): 298.5912,
#  ('Atreuco', 'Barker'): 480.9814,
#  ('Atreuco', 'Benito Juarez'): 431.5583,
#  ('Atreuco', 'Bragado'): 432.414,
#  ('Atreuco', 'Brandsen'): 629.1041,
#  ('Atreuco', 'Ramallo'): 663.796,
#  ('Atreuco', 'Cañuelas'): 565.5233000000001,
#  ('Atreuco', 'Capilla del Señor'): 612.1795999999999,
#  ('Atreuco', 'Laboulaye'): 472.241,
#  ('Atreuco', 'Los Cisnes'): 585.207,
#  ('Atreuco', 'Rio Cuarto'): 496.84590000000003,
#  ('Atreuco', 'Chacabuco'): 521.5346,
#  ('Atreuco', 'Cofco Balcarce'): 646.0515,
#  ('Atreuco', 'Concepción del Uruguay'): 839.7955999999999,
#  ('Atreuco', 'Deheza'): 566.6472,
#  ('Atreuco', 'Villa Paranacito'): 719.1871,
#  ('Atreuco', 'Dovales (Tandil)'): 539.9815,
#  ('Atreuco', 'Flor de Oro, Reconquista'): 1137.7476000000001,
#  ('Atreuco', 'Gral. Levalle'): 451.62309999999997,
#  ('Atreuco', 'H. Lagos '): 679.266,
#  ('Atreuco', 'La Carlota'): 561.1493,
#  ('Atreuco', 'Laplacette'): 452.685,
#  ('Atreuco', 'La Toma (PALADINI)'): 613.5025,
#  ('Atreuco', 'Labordeboy'): 577.546,
#  ('Atreuco', 'Lincoln'): 416.8451,
#  ('Atreuco', 'Lobos'): 531.677,
#  ('Atreuco', 'Madariaga'): 733.0097,
#  ('Atreuco', 'Naón'): 416.6582,
#  ('Atreuco', 'Navarro'): 556.471,
#  ('Atreuco', 'Otamendi'): 632.3721999999999,
#  ('Atreuco', 'Pehuajó'): 275.7457,
#  ('Atreuco', 'Pergamino'): 565.7888,
#  ('Atreuco', 'Peyrano'): 614.3936,
#  ('Atreuco', 'Pieres'): 553.3301,
#  ('Atreuco', 'Pilar'): 594.3711,
#  ('Atreuco', 'Roldán'): 650.2961,
#  ('Atreuco', 'Rosario'): 703.2675,
#  ('Atreuco', 'Saladillo'): 448.5775,
#  ('Atreuco', 'Salto'): 568.2455,
#  ('Atreuco', 'San Andrés de Giles'): 567.476,
#  ('Atreuco', 'San Jerónimo'): 655.9472,
#  ('Atreuco', 'San Pedro'): 660.0485,
#  ('Atreuco', 'Tres Arroyos'): 392.81109999999995,
#  ('Atreuco', 'Vicuña Mackena '): 403.2253,
#  ('Atreuco', 'Villa Elisa'): 640.3311,
#  ('Atreuco', 'Villegas'): 307.1173,
#  ('Atreuco', 'Carlos Casares'): 327.0477,
#  ('Atreuco', 'Colón'): 571.0078000000001,
#  ('Atreuco', 'Chascomús'): 696.236,
#  ('Atreuco', 'Chivilcoy'): 483.02979999999997,
#  ('Atreuco', 'Daireaux'): 235.2,
#  ('Atreuco', 'Guaminí'): 155.14620000000002,
#  ('Atreuco', 'Junín'): 474.7621,
#  ('Atreuco', 'Lobería'): 581.5068,
#  ('Atreuco', 'San Manuel'): 616.4918,
#  ('Atreuco', 'San Miguel del Monte'): 567.9384,
#  ('Atreuco', 'Quequén'): 533.4273000000001,
#  ('Atreuco', 'Tosquitas'): 418.3451,
#  ('Atreuco', 'Catriló'): 112.8197,
#  ('Atreuco', 'Villa Mercedes'): 532.7962,
#  ('Atreuco', 'Lima'): 663.1588,
#  ('Atreuco', 'Balsa'): 434.4385,
#  ('Atreuco', 'Lezama'): 690.5931999999999,
#  ('Atreuco', 'Olavarría'): 411.2577,
#  ('Atreuco', 'Open Door'): 583.9784000000001,
#  ('Atreuco', 'Wheelwright'): 579.3121,
#  ('La Merced', '9 de Julio'): 349.0135,
#  ('La Merced', 'Arrecifes'): 565.5248,
#  ('La Merced', 'Azul'): 472.6816,
#  ('La Merced', 'Bahia Blanca'): 313.4618,
#  ('La Merced', 'Barker'): 495.852,
#  ('La Merced', 'Benito Juarez'): 446.4289,
#  ('La Merced', 'Bragado'): 402.7396,
#  ('La Merced', 'Brandsen'): 643.9746,
#  ('La Merced', 'Ramallo'): 634.1215,
#  ('La Merced', 'Cañuelas'): 580.3939,
#  ('La Merced', 'Capilla del Señor'): 582.5051,
#  ('La Merced', 'Laboulaye'): 442.5666,
#  ('La Merced', 'Los Cisnes'): 555.5326,
#  ('La Merced', 'Rio Cuarto'): 504.3563,
#  ('La Merced', 'Chacabuco'): 491.8602,
#  ('La Merced', 'Cofco Balcarce'): 660.9221,
#  ('La Merced', 'Concepción del Uruguay'): 810.1211,
#  ('La Merced', 'Deheza'): 574.1576,
#  ('La Merced', 'Villa Paranacito'): 689.5126,
#  ('La Merced', 'Dovales (Tandil)'): 554.8521,
#  ('La Merced', 'Flor de Oro, Reconquista'): 1108.0732,
#  ('La Merced', 'Gral. Levalle'): 385.7446,
#  ('La Merced', 'H. Lagos '): 649.5915,
#  ('La Merced', 'La Carlota'): 531.4749,
#  ('La Merced', 'Laplacette'): 423.01059999999995,
#  ('La Merced', 'La Toma (PALADINI)'): 621.0128000000001,
#  ('La Merced', 'Labordeboy'): 547.8716,
#  ('La Merced', 'Lincoln'): 387.1706,
#  ('La Merced', 'Lobos'): 546.5475,
#  ('La Merced', 'Madariaga'): 747.8803,
#  ('La Merced', 'Naón'): 386.9838,
#  ('La Merced', 'Navarro'): 571.3415,
#  ('La Merced', 'Otamendi'): 647.2428000000001,
#  ('La Merced', 'Pehuajó'): 246.07129999999998,
#  ('La Merced', 'Pergamino'): 536.1143000000001,
#  ('La Merced', 'Peyrano'): 584.7191,
#  ('La Merced', 'Pieres'): 568.2008000000001,
#  ('La Merced', 'Pilar'): 564.6967,
#  ('La Merced', 'Roldán'): 620.6216999999999,
#  ('La Merced', 'Rosario'): 673.593,
#  ('La Merced', 'Saladillo'): 463.44809999999995,
#  ('La Merced', 'Salto'): 538.5711,
#  ('La Merced', 'San Andrés de Giles'): 537.8015,
#  ('La Merced', 'San Jerónimo'): 663.4575,
#  ('La Merced', 'San Pedro'): 630.374,
#  ('La Merced', 'Tres Arroyos'): 407.68170000000003,
#  ('La Merced', 'Vicuña Mackena '): 410.7356,
#  ('La Merced', 'Villa Elisa'): 610.6567,
#  ('La Merced', 'Villegas'): 277.4428,
#  ('La Merced', 'Carlos Casares'): 297.3733,
#  ('La Merced', 'Colón'): 541.3334,
#  ('La Merced', 'Chascomús'): 711.1066,
#  ('La Merced', 'Chivilcoy'): 453.35540000000003,
#  ('La Merced', 'Daireaux'): 250.0706,
#  ('La Merced', 'Guaminí'): 170.01670000000001,
#  ('La Merced', 'Junín'): 445.08759999999995,
#  ('La Merced', 'Lobería'): 596.3774000000001,
#  ('La Merced', 'San Manuel'): 631.3623,
#  ('La Merced', 'San Miguel del Monte'): 582.809,
#  ('La Merced', 'Quequén'): 548.2979,
#  ('La Merced', 'Tosquitas'): 425.8555,
#  ('La Merced', 'Catriló'): 83.1453,
#  ('La Merced', 'Villa Mercedes'): 540.3066,
#  ('La Merced', 'Lima'): 633.4844,
#  ('La Merced', 'Balsa'): 404.7641,
#  ('La Merced', 'Lezama'): 705.4638,
#  ('La Merced', 'Olavarría'): 426.12829999999997,
#  ('La Merced', 'Open Door'): 554.304,
#  ('La Merced', 'Wheelwright'): 549.6378000000001,
#  ('Los Robles Lonquimay', '9 de Julio'): 302.6472,
#  ('Los Robles Lonquimay', 'Arrecifes'): 519.1584,
#  ('Los Robles Lonquimay', 'Azul'): 429.33759999999995,
#  ('Los Robles Lonquimay', 'Bahia Blanca'): 362.4922,
#  ('Los Robles Lonquimay', 'Barker'): 537.2868000000001,
#  ('Los Robles Lonquimay', 'Benito Juarez'): 487.86359999999996,
#  ('Los Robles Lonquimay', 'Bragado'): 356.3732,
#  ('Los Robles Lonquimay', 'Brandsen'): 600.6306,
#  ('Los Robles Lonquimay', 'Ramallo'): 587.7552,
#  ('Los Robles Lonquimay', 'Cañuelas'): 537.05,
#  ('Los Robles Lonquimay', 'Capilla del Señor'): 536.1389,
#  ('Los Robles Lonquimay', 'Laboulaye'): 396.20029999999997,
#  ('Los Robles Lonquimay', 'Los Cisnes'): 509.1663,
#  ('Los Robles Lonquimay', 'Rio Cuarto'): 436.383,
#  ('Los Robles Lonquimay', 'Chacabuco'): 445.4939,
#  ('Los Robles Lonquimay', 'Cofco Balcarce'): 617.5781,
#  ('Los Robles Lonquimay', 'Concepción del Uruguay'): 763.7549,
#  ('Los Robles Lonquimay', 'Deheza'): 506.1843,
#  ('Los Robles Lonquimay', 'Villa Paranacito'): 643.1463,
#  ('Los Robles Lonquimay', 'Dovales (Tandil)'): 511.50809999999996,
#  ('Los Robles Lonquimay', 'Flor de Oro, Reconquista'): 1061.707,
#  ('Los Robles Lonquimay', 'Gral. Levalle'): 317.7713,
#  ('Los Robles Lonquimay', 'H. Lagos '): 603.2252,
#  ('Los Robles Lonquimay', 'La Carlota'): 485.10859999999997,
#  ('Los Robles Lonquimay', 'Laplacette'): 376.6442,
#  ('Los Robles Lonquimay', 'La Toma (PALADINI)'): 553.0396,
#  ('Los Robles Lonquimay', 'Labordeboy'): 501.5053,
#  ('Los Robles Lonquimay', 'Lincoln'): 340.8043,
#  ('Los Robles Lonquimay', 'Lobos'): 503.2036,
#  ('Los Robles Lonquimay', 'Madariaga'): 704.5363000000001,
#  ('Los Robles Lonquimay', 'Naón'): 340.6175,
#  ('Los Robles Lonquimay', 'Navarro'): 527.9975,
#  ('Los Robles Lonquimay', 'Otamendi'): 704.8673,
#  ('Los Robles Lonquimay', 'Pehuajó'): 199.70489999999998,
#  ('Los Robles Lonquimay', 'Pergamino'): 489.748,
#  ('Los Robles Lonquimay', 'Peyrano'): 538.3528,
#  ('Los Robles Lonquimay', 'Pieres'): 617.2312,
#  ('Los Robles Lonquimay', 'Pilar'): 518.3304,
#  ('Los Robles Lonquimay', 'Roldán'): 574.2554,
#  ('Los Robles Lonquimay', 'Rosario'): 627.2266999999999,
#  ('Los Robles Lonquimay', 'Saladillo'): 420.10409999999996,
#  ('Los Robles Lonquimay', 'Salto'): 492.2048,
#  ('Los Robles Lonquimay', 'San Andrés de Giles'): 491.4352,
#  ('Los Robles Lonquimay', 'San Jerónimo'): 595.4843000000001,
#  ('Los Robles Lonquimay', 'San Pedro'): 584.0078000000001,
#  ('Los Robles Lonquimay', 'Tres Arroyos'): 456.7122,
#  ('Los Robles Lonquimay', 'Vicuña Mackena '): 342.7624,
#  ('Los Robles Lonquimay', 'Villa Elisa'): 564.2905,
#  ('Los Robles Lonquimay', 'Villegas'): 231.0765,
#  ('Los Robles Lonquimay', 'Carlos Casares'): 251.0069,
#  ('Los Robles Lonquimay', 'Colón'): 494.96709999999996,
#  ('Los Robles Lonquimay', 'Chascomús'): 667.7626,
#  ('Los Robles Lonquimay', 'Chivilcoy'): 406.989,
#  ('Los Robles Lonquimay', 'Daireaux'): 299.1011,
#  ('Los Robles Lonquimay', 'Guaminí'): 219.0472,
#  ('Los Robles Lonquimay', 'Junín'): 398.7213,
#  ('Los Robles Lonquimay', 'Lobería'): 624.6435,
#  ('Los Robles Lonquimay', 'San Manuel'): 588.0184,
#  ('Los Robles Lonquimay', 'San Miguel del Monte'): 539.465,
#  ('Los Robles Lonquimay', 'Quequén'): 597.3283,
#  ('Los Robles Lonquimay', 'Tosquitas'): 357.8822,
#  ('Los Robles Lonquimay', 'Catriló'): 36.779,
#  ('Los Robles Lonquimay', 'Villa Mercedes'): 472.3333,
#  ('Los Robles Lonquimay', 'Lima'): 587.1181,
#  ('Los Robles Lonquimay', 'Balsa'): 358.39779999999996,
#  ('Los Robles Lonquimay', 'Lezama'): 662.1198,
#  ('Los Robles Lonquimay', 'Olavarría'): 382.7843,
#  ('Los Robles Lonquimay', 'Open Door'): 507.9376,
#  ('Los Robles Lonquimay', 'Wheelwright'): 503.2715,
#  ('San Francisco', '9 de Julio'): 346.0523,
#  ('San Francisco', 'Arrecifes'): 562.5636,
#  ('San Francisco', 'Azul'): 472.7428,
#  ('San Francisco', 'Bahia Blanca'): 335.70279999999997,
#  ('San Francisco', 'Barker'): 518.093,
#  ('San Francisco', 'Benito Juarez'): 468.67,
#  ('San Francisco', 'Bragado'): 399.77840000000003,
#  ('San Francisco', 'Brandsen'): 644.0358,
#  ('San Francisco', 'Ramallo'): 631.1603,
#  ('San Francisco', 'Cañuelas'): 580.4551,
#  ('San Francisco', 'Capilla del Señor'): 579.544,
#  ('San Francisco', 'Laboulaye'): 439.60540000000003,
#  ('San Francisco', 'Los Cisnes'): 552.5714,
#  ('San Francisco', 'Rio Cuarto'): 501.39509999999996,
#  ('San Francisco', 'Chacabuco'): 488.899,
#  ('San Francisco', 'Cofco Balcarce'): 660.9833000000001,
#  ('San Francisco', 'Concepción del Uruguay'): 807.16,
#  ('San Francisco', 'Deheza'): 571.1964,
#  ('San Francisco', 'Villa Paranacito'): 686.5515,
#  ('San Francisco', 'Dovales (Tandil)'): 554.9133,
#  ('San Francisco', 'Flor de Oro, Reconquista'): 1105.1121,
#  ('San Francisco', 'Gral. Levalle'): 382.78340000000003,
#  ('San Francisco', 'H. Lagos '): 646.6303,
#  ('San Francisco', 'La Carlota'): 528.5137,
#  ('San Francisco', 'Laplacette'): 420.04940000000005,
#  ('San Francisco', 'La Toma (PALADINI)'): 618.0516,
#  ('San Francisco', 'Labordeboy'): 544.9104,
#  ('San Francisco', 'Lincoln'): 384.2095,
#  ('San Francisco', 'Lobos'): 546.6087,
#  ('San Francisco', 'Madariaga'): 747.9414,
#  ('San Francisco', 'Naón'): 384.02259999999995,
#  ('San Francisco', 'Navarro'): 571.4027,
#  ('San Francisco', 'Otamendi'): 669.4838000000001,
#  ('San Francisco', 'Pehuajó'): 243.11010000000002,
#  ('San Francisco', 'Pergamino'): 533.1531,
#  ('San Francisco', 'Peyrano'): 581.758,
#  ('San Francisco', 'Pieres'): 590.4418000000001,
#  ('San Francisco', 'Pilar'): 561.7355,
#  ('San Francisco', 'Roldán'): 617.6605,
#  ('San Francisco', 'Rosario'): 670.6318,
#  ('San Francisco', 'Saladillo'): 463.5092,
#  ('San Francisco', 'Salto'): 535.6099,
#  ('San Francisco', 'San Andrés de Giles'): 534.8403000000001,
#  ('San Francisco', 'San Jerónimo'): 660.4963,
#  ('San Francisco', 'San Pedro'): 627.4129,
#  ('San Francisco', 'Tres Arroyos'): 429.9228,
#  ('San Francisco', 'Vicuña Mackena '): 407.7745,
#  ('San Francisco', 'Villa Elisa'): 607.6956,
#  ('San Francisco', 'Villegas'): 274.48159999999996,
#  ('San Francisco', 'Carlos Casares'): 294.41209999999995,
#  ('San Francisco', 'Colón'): 538.3721999999999,
#  ('San Francisco', 'Chascomús'): 711.1678,
#  ('San Francisco', 'Chivilcoy'): 450.3942,
#  ('San Francisco', 'Daireaux'): 272.31170000000003,
#  ('San Francisco', 'Guaminí'): 192.25779999999997,
#  ('San Francisco', 'Junín'): 442.12640000000005,
#  ('San Francisco', 'Lobería'): 618.6185,
#  ('San Francisco', 'San Manuel'): 631.4235,
#  ('San Francisco', 'San Miguel del Monte'): 582.8701,
#  ('San Francisco', 'Quequén'): 570.539,
#  ('San Francisco', 'Tosquitas'): 422.8943,
#  ('San Francisco', 'Catriló'): 80.1841,
#  ('San Francisco', 'Villa Mercedes'): 537.3454,
#  ('San Francisco', 'Lima'): 630.5232,
#  ('San Francisco', 'Balsa'): 401.8029,
#  ('San Francisco', 'Lezama'): 705.525,
#  ('San Francisco', 'Olavarría'): 426.1895,
#  ('San Francisco', 'Open Door'): 551.3428,
#  ('San Francisco', 'Wheelwright'): 546.6766,
#  ('Valle Argentino', '9 de Julio'): 386.3544,
#  ('Valle Argentino', 'Arrecifes'): 602.8656,
#  ('Valle Argentino', 'Azul'): 465.4775,
#  ('Valle Argentino', 'Bahia Blanca'): 306.25759999999997,
#  ('Valle Argentino', 'Barker'): 488.64779999999996,
#  ('Valle Argentino', 'Benito Juarez'): 439.2248,
#  ('Valle Argentino', 'Bragado'): 440.0804,
#  ('Valle Argentino', 'Brandsen'): 636.7705,
#  ('Valle Argentino', 'Ramallo'): 671.4624,
#  ('Valle Argentino', 'Cañuelas'): 573.1898,
#  ('Valle Argentino', 'Capilla del Señor'): 619.846,
#  ('Valle Argentino', 'Laboulaye'): 479.9075,
#  ('Valle Argentino', 'Los Cisnes'): 592.8735,
#  ('Valle Argentino', 'Rio Cuarto'): 492.16,
#  ('Valle Argentino', 'Chacabuco'): 529.201,
#  ('Valle Argentino', 'Cofco Balcarce'): 653.718,
#  ('Valle Argentino', 'Concepción del Uruguay'): 847.462,
#  ('Valle Argentino', 'Deheza'): 561.9613,
#  ('Valle Argentino', 'Villa Paranacito'): 726.8535,
#  ('Valle Argentino', 'Dovales (Tandil)'): 547.648,
#  ('Valle Argentino', 'Flor de Oro, Reconquista'): 1145.4141000000002,
#  ('Valle Argentino', 'Gral. Levalle'): 446.9373,
#  ('Valle Argentino', 'H. Lagos '): 686.9324,
#  ('Valle Argentino', 'La Carlota'): 568.8158000000001,
#  ('Valle Argentino', 'Laplacette'): 460.3514,
#  ('Valle Argentino', 'La Toma (PALADINI)'): 608.8166,
#  ('Valle Argentino', 'Labordeboy'): 585.2124,
#  ('Valle Argentino', 'Lincoln'): 424.5115,
#  ('Valle Argentino', 'Lobos'): 539.3434,
#  ('Valle Argentino', 'Madariaga'): 740.6761,
#  ('Valle Argentino', 'Naón'): 424.3246,
#  ('Valle Argentino', 'Navarro'): 564.1374000000001,
#  ('Valle Argentino', 'Otamendi'): 640.0386,
#  ('Valle Argentino', 'Pehuajó'): 283.41209999999995,
#  ('Valle Argentino', 'Pergamino'): 573.4552,
#  ('Valle Argentino', 'Peyrano'): 622.06,
#  ('Valle Argentino', 'Pieres'): 560.9966,
#  ('Valle Argentino', 'Pilar'): 602.0376,
#  ('Valle Argentino', 'Roldán'): 657.9625,
#  ('Valle Argentino', 'Rosario'): 710.9339,
#  ('Valle Argentino', 'Saladillo'): 456.2439,
#  ('Valle Argentino', 'Salto'): 575.912,
#  ('Valle Argentino', 'San Andrés de Giles'): 575.1423000000001,
#  ('Valle Argentino', 'San Jerónimo'): 651.2613,
#  ('Valle Argentino', 'San Pedro'): 667.7149000000001,
#  ('Valle Argentino', 'Tres Arroyos'): 400.4776,
#  ('Valle Argentino', 'Vicuña Mackena '): 398.5395,
#  ('Valle Argentino', 'Villa Elisa'): 647.9975999999999,
#  ('Valle Argentino', 'Villegas'): 314.7837,
#  ('Valle Argentino', 'Carlos Casares'): 334.7141,
#  ('Valle Argentino', 'Colón'): 578.6743,
#  ('Valle Argentino', 'Chascomús'): 703.9025,
#  ('Valle Argentino', 'Chivilcoy'): 490.69620000000003,
#  ('Valle Argentino', 'Daireaux'): 242.8665,
#  ('Valle Argentino', 'Guaminí'): 162.8126,
#  ('Valle Argentino', 'Junín'): 482.4285,
#  ('Valle Argentino', 'Lobería'): 589.1733,
#  ('Valle Argentino', 'San Manuel'): 624.1582,
#  ('Valle Argentino', 'San Miguel del Monte'): 575.6048000000001,
#  ('Valle Argentino', 'Quequén'): 541.0938000000001,
#  ('Valle Argentino', 'Tosquitas'): 413.6593,
#  ('Valle Argentino', 'Catriló'): 120.4862,
#  ('Valle Argentino', 'Villa Mercedes'): 528.1103,
#  ('Valle Argentino', 'Lima'): 670.8253000000001,
#  ('Valle Argentino', 'Balsa'): 442.10490000000004,
#  ('Valle Argentino', 'Lezama'): 698.2596,
#  ('Valle Argentino', 'Olavarría'): 418.9242,
#  ('Valle Argentino', 'Open Door'): 591.6448,
#  ('Valle Argentino', 'Wheelwright'): 586.9786}

# %%
df = pd.DataFrame(results)
df.head()
# Out:
#                Atreuco  La Merced  Los Robles Lonquimay  San Francisco  \
# 9 de Julio    378.6880   349.0135              302.6472       346.0523
# Arrecifes     595.1991   565.5248              519.1584       562.5636
# Azul          457.8110   472.6816              429.3376       472.7428
# Bahia Blanca  298.5912   313.4618              362.4922       335.7028
# Barker        480.9814   495.8520              537.2868       518.0930
#
#               Valle Argentino
# 9 de Julio           386.3544
# Arrecifes            602.8656
# Azul                 465.4775
# Bahia Blanca         306.2576
# Barker               488.6478

# %%
# --- Inputs (examples) ---
# espcul_coord_snapped = {"O1": (-37.621628, -59.3359883), "O2": (-37.700000, -59.200000)}
# origen_zona = {"O1": "BA SDE S", "O2": "BA SDE S"}
# destinos_coord = {"Flor de Oro, Reconquista": (-29.14, -59.64), "Gral. Levalle": (-34.01, -63.92)}

def build_distance_table(
    espcul_coord_snapped: dict,
    origen_zona: dict,
    destinos_coord: dict,
    profile: str = "driving",
    base_url: str = "http://router.project-osrm.org",
    include_distance: bool = True,
) -> pd.DataFrame:
    """
    Build a long-format OD table using OSRM's Table service.
    Returns a DataFrame with columns:
    zona, idest, origen_x, origen_y, destino, destino_x, destino_y, distancia_m, duracion_s
    """

    # --- Keys and coordinate lists ---
    origin_keys = list(espcul_coord_snapped.keys())
    dest_keys   = list(destinos_coord.keys())

    all_coords = []
    # Append origins first (lon,lat)
    for ok in origin_keys:
        o = espcul_coord_snapped[ok]
        if not (isinstance(o, tuple) and len(o) == 2):
            raise ValueError(f"Origin '{ok}' has invalid coordinate format: {o}")
        lat, lon = o
        all_coords.append(f"{lon},{lat}")  # OSRM expects lon,lat

    # Then destinations (lon,lat)
    for dk in dest_keys:
        d = destinos_coord[dk]
        if not (isinstance(d, tuple) and len(d) == 2):
            raise ValueError(f"Destination '{dk}' has invalid coordinate format: {d}")
        lat, lon = d
        all_coords.append(f"{lon},{lat}")

    coords_str = ";".join(all_coords)

    # Indices for sources and destinations in the unified coordinate list
    sources_indices = ";".join(str(i) for i in range(len(origin_keys)))
    dest_start      = len(origin_keys)
    dest_indices    = ";".join(str(dest_start + i) for i in range(len(dest_keys)))

    # --- Request URL (ask for both durations and distances if needed) ---
    annotations = "duration,distance" if include_distance else "duration"
    url = (
        f"{base_url}/table/v1/{profile}/{coords_str}"
        f"?sources={sources_indices}&destinations={dest_indices}"
        f"&annotations={annotations}"
    )

    # --- Call OSRM ---
    resp = requests.get(url, timeout=60)
    resp.raise_for_status()
    data = resp.json()
    if data.get("code") != "Ok":
        raise RuntimeError(f"OSRM table error: {data.get('code')}")

    durations = data.get("durations")
    distances = data.get("distances") if include_distance else None
    if durations is None:
        raise RuntimeError("OSRM response missing 'durations'")

    # --- Flatten to long rows ---
    records = []
    for i, ok in enumerate(origin_keys):
        zona = origen_zona.get(ok, None)  # zone per origin id
        o_lat, o_lon = espcul_coord_snapped[ok]
        o_x, o_y = o_lon, o_lat  # x = lon, y = lat

        for j, dk in enumerate(dest_keys):
            d_lat, d_lon = destinos_coord[dk]
            d_x, d_y = d_lon, d_lat

            dur_s = durations[i][j] if durations and durations[i] else None
            dist_m = distances[i][j] if (distances and distances[i]) else None

            # Build row
            records.append({
                "zona": zona,
                "idest": ok,
                "origen_x": o_x,
                "origen_y": o_y,
                "destino": dk,
                "destino_x": d_x,
                "destino_y": d_y,
                "distancia_km": dist_m,
                "duracion_h": dur_s,
            })

    df = pd.DataFrame.from_records(records)

    # Optional: order columns to match your screenshot style
    cols = ["zona", "idest", "origen_x", "origen_y", "destino", "destino_x", "destino_y", "distancia_km", "duracion_h"]
    df = df[cols]
    df.distancia_km = df.distancia_km / 1000
    df.duracion_h = df.duracion_h / 3600

    return df


# --- Example usage ---
df_od = build_distance_table(espcul_coord_snapped, origen_zona, destinos_coord)
df_od.head()

# %%
path = "./outputs"

if not os.path.exists(path):
    os.makedirs(path)

# df.to_csv('matrix.csv', index=False)
df_od.to_excel('./outputs/matriz_de_distancias_table_service.xlsx', index=False)
